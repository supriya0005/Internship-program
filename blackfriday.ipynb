# %% [markdown]
# <a href="https://colab.research.google.com/github/supriya0005/Internship-program/blob/main/blackfriday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/BlackFriday.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
print(df.isnull().sum)
# Out:
# <bound method DataFrame.sum of         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 461685    False       False   False  False       False          False
# 461686    False       False   False  False       False          False
# 461687    False       False   False  False       False          False
# 461688    False       False   False  False       False          False
# 461689    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                            False           False               False
# 1                            False           False               False
# 2                            False           False               False
# 3                            False           False               False
# 4                            False           False               False
# ...                            ...             ...                 ...
# 461685                       False           False               False
# 461686                       False           False               False
# 461687                       False           False               False
# 461688                       False           False               False
# 461689                       False           False               False
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                     True                True     False
# 1                    False               False     False
# 2                     True                True     False
# 3                    False                True     False
# 4                     True                True     False
# ...                    ...                 ...       ...
# 461685               False                True     False
# 461686               False                True     False
# 461687                True                True     False
# 461688               False               False     False
# 461689               False                True      True
#
# [461690 rows x 12 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461690 entries, 0 to 461689
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     461690 non-null  int64
#  1   Product_ID                  461690 non-null  object
#  2   Gender                      461690 non-null  object
#  3   Age                         461690 non-null  object
#  4   Occupation                  461690 non-null  int64
#  5   City_Category               461690 non-null  object
#  6   Stay_In_Current_City_Years  461690 non-null  object
#  7   Marital_Status              461690 non-null  int64
#  8   Product_Category_1          461690 non-null  int64
#  9   Product_Category_2          318271 non-null  float64
#  10  Product_Category_3          141209 non-null  float64
#  11  Purchase                    461689 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 42.3+ MB

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 461658  1005075  P00034742      M  51-55           6             C
# 461660  1005076  P00242742      M  26-35           3             B
# 461666  1005077  P00221442      M  26-35           2             A
# 461670  1005077  P00059442      M  26-35           2             A
# 461688  1005077  P00102642      M  26-35           2             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# 6                               2               1                   1
# 13                              1               1                   1
# 14                              1               0                   5
# 16                              1               0                   2
# ...                           ...             ...                 ...
# 461658                          1               1                   5
# 461660                         4+               0                   1
# 461666                          0               0                   1
# 461670                          0               0                   6
# 461688                          0               0                   4
#
#         Product_Category_2  Product_Category_3  Purchase
# 1                      6.0                14.0   15200.0
# 6                      8.0                17.0   19215.0
# 13                     2.0                 5.0   15665.0
# 14                     8.0                14.0    5378.0
# 16                     3.0                 4.0   13055.0
# ...                    ...                 ...       ...
# 461658                14.0                17.0    5304.0
# 461660                 2.0                 9.0   15457.0
# 461666                 2.0                 5.0   15469.0
# 461670                 8.0                16.0   12594.0
# 461688                 8.0                 9.0    3526.0
#
# [141209 rows x 12 columns]

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00172642',
#        'P00038642', 'P00211742'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
data = pd.DataFrame({'Ratio':[len(df[df['Gender']=='M']),len(df[df['Gender']=='F'])]}, index = ['Male','Female'])
data.plot.pie(y='Ratio',figsize =(6,6), autopct = "%.1f" )
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind = 'bar',figsize = (6,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Age').size().plot(kind = 'bar', figsize = (12,6), title = 'Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
data = df.groupby('Age')['Product_ID'].nunique().reset_index() #nunique = number of unique
data.columns = ['Age','Products']

# %%
data.plot.bar(x = 'Age' , figsize = (7,6))
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize = (12,6), title = 'Amount Spend by Age')
# Out:
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %%
df.groupby('Age')['Purchase'].mean().plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
 df.groupby('Age').size().plot(kind = 'bar', figsize = (12,6), title = 'Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Age", hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Gender", hue = 'Age', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = "Marital_Status", hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue = 'Age', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'Age', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Marital_Status', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue = 'Age',data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df['MaritalGender'] = (
    df['Gender'] + "_" + df['Marital_Status'].astype(str)
)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_2  Purchase  \
# 0                          2               0                 NaN    8370.0
# 1                          2               0                 6.0   15200.0
# 2                          2               0                 NaN    1422.0
# 3                          2               0                14.0    1057.0
# 4                         4+               0                 NaN    7969.0
#
#   MaritalGender
# 0           F_0
# 1           F_0
# 2           F_0
# 3           F_0
# 4           M_0

# %%
sns.countplot(x = df['MaritalGender'])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x = df['Age'], hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = df['Stay_In_Current_City_Years'], hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'], hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# <a href="https://colab.research.google.com/github/supriya0005/Internship-program/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

from google import genai
from getpass import getpass

api_key = getpass("Enter your Gemini API Key: ")

client = genai.Client(api_key=api_key)

print("🤖 Gemini Chatbot")
print("Type 'exit' to quit.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Bot: Goodbye!")
        break

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=user_input,
    )

    print("Bot:", response.text)
    print()
# Out:
# Enter your Gemini API Key: ··········
# 🤖 Gemini Chatbot
# Type 'exit' to quit.
#
# You: hello
# Bot: Hello! How can I help you today?
#
# You: who is supriya
# Bot: "Supriya" is a common name, particularly in India, so there are many individuals who bear it. To provide a helpful answer, I'll list some of the most well-known people named Supriya:
#
# 1.  **Supriya Pathak Kapur:** A veteran Indian actress primarily known for her work in Hindi cinema and television. She is widely recognized for her role as "Hansaben" in the popular TV series *Khichdi*. She has also received critical acclaim for films like *Goliyon Ki Raasleela Ram-Leela* and *Delhi-6*. She is the daughter of actress Dina Pathak, sister of Ratna Pathak Shah, and wife of actor Pankaj Kapur.
#
# 2.  **Supriya Sule:** A prominent Indian politician and Member of Parliament (Lok Sabha) from the Baramati constituency in Maharashtra. She is a member of the Nationalist Congress Party (NCP) and the daughter of Sharad Pawar, a veteran Indian politician.
#
# 3.  **Supriya Devi:** (1933 – 2018) A legendary Indian actress who worked primarily in Bengali cinema. She was one of the most iconic figures of the golden age of Bengali cinema and known for her strong performances in films like Ritwik Ghatak's *Meghe Dhaka Tara*. She was awarded the Padma Shri, India's fourth highest civilian award.
#
# 4.  **Supriya Karnik:** An Indian actress who has appeared in numerous Bollywood films and television shows, often playing supporting roles, sometimes with a comedic or negative touch.
#
# If you had a specific Supriya in mind, please provide more context!

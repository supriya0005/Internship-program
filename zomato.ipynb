# %% [markdown]
# <a href="https://colab.research.google.com/github/supriya0005/Internship-program/blob/main/zomato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

# %%
df = pd.read_csv("/content/Zomato-data-.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_781/3767048758.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/Zomato-data-.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df.head()

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df['rate'].unique()

# %%
df.dropna(inplace= True)
df.head()

# %%
df.rename(columns ={'approx_cost(for two people)':'cost2plates','listed_in(type)':'type'},inplace = True)

# %%
df.head()

# %%
df['votes'].unique()

# %%
df['cost2plates'].unique()

# %%
# removing comma from cost2plates

def handlecomma(value):
    value = str(value)
    if ',' in value:
        value = value.replace(',', ' ')
        return float(value)
    else:
        return float(value)

df['cost2plates'] = df['cost2plates'].apply(handlecomma)
df['cost2plates'].unique()

# %%
df.head()

# %%
rest_types = df['type'].value_counts(ascending  = False)
rest_types

# %%
#Count Plot of Various plate cost
plt.figure(figsize = (16,10))
ax = sns.countplot(df['cost2plates'])
plt.xticks(rotation=0)

# %%
plt.figure(figsize = (6,6))
sns.boxplot(x = 'online_order', y = 'rate', data = df)
